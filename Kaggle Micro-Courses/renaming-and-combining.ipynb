# %% [markdown]
# **[Pandas Micro-Course Home Page](https://www.kaggle.com/learn/pandas)**
#
# ---

# %% [markdown]
# ## Intro
#
# This is the workbook part of the "Renaming and combining" section of the Advanced Pandas tutorial. For the reference section, click [here](https://www.kaggle.com/residentmario/renaming-and-combining-reference).
#
# Renaming is covered in its own section in the ["Essential Basic Functionality"](https://pandas.pydata.org/pandas-docs/stable/basics.html#renaming-mapping-labels) section of the extensive official documentation. Combining is covered by the ["Merge, join, concatenate"](https://pandas.pydata.org/pandas-docs/stable/merging.html) section there.

# %%
import pandas as pd

reviews = pd.read_csv("../input/wine-reviews/winemag-data-130k-v2.csv", index_col=0)

from learntools.core import binder; binder.bind(globals())
from learntools.pandas.renaming_and_combining import *
print("Setup complete.")
# Out:
# Setup complete.

# %% [markdown]
# # Exercises
#
# View the first several lines of your data by running the cell below:

# %%
reviews.head()
# Out:
#     country         ...                        winery
# 0     Italy         ...                       Nicosia
# 1  Portugal         ...           Quinta dos Avidagos
# 2        US         ...                     Rainstorm
# 3        US         ...                    St. Julian
# 4        US         ...                  Sweet Cheeks
#
# [5 rows x 13 columns]

# %% [markdown]
# ## 1.
# `region_1` and `region_2` are pretty uninformative names for locale columns in the dataset. Create a copy of `reviews` with these columns renamed to `region` and `locale`, respectively.

# %%
# Your code here
#renamed = reviews.rename(columns={'region_1':'region', 'region_2':'locale'})
renamed = reviews.rename(columns=dict(region_1='region', region_2='locale'))
q1.check()
# Out:
# Correct

# %%
#q1.hint()
q1.solution()
# Out:
# Solution:
# ```python
# renamed = reviews.rename(columns=dict(region_1='region', region_2='locale'))
# ```

# %% [markdown]
# ## 2.
# Set the index name in the dataset to `wines`.

# %%
reindexed = reviews.rename_axis("wines",axis='rows')

q2.check()
# Out:
# Correct

# %%
#q2.hint()
q2.solution()
# Out:
# Solution:
# ```python
# reindexed = reviews.rename_axis('wines', axis='rows')
# ```

# %% [markdown]
# ## 3.
# The [Things on Reddit](https://www.kaggle.com/residentmario/things-on-reddit/data) dataset includes product links from a selection of top-ranked forums ("subreddits") on reddit.com. Run the cell below to load a dataframe of products mentioned on the */r/gaming* subreddit and another dataframe for products mentioned on the *r//movies* subreddit.

# %%
gaming_products = pd.read_csv("../input/things-on-reddit/top-things/top-things/reddits/g/gaming.csv")
gaming_products['subreddit'] = "r/gaming"
movie_products = pd.read_csv("../input/things-on-reddit/top-things/top-things/reddits/m/movies.csv")
movie_products['subreddit'] = "r/movies"

# %% [markdown]
# Create a `DataFrame` of products mentioned on *either* subreddit.

# %%
combined_products = pd.concat([gaming_products, movie_products])

q3.check()
# Out:
# Correct

# %%
#q3.hint()
q3.solution()
# Out:
# Solution:
# ```python
# combined_products = pd.concat([gaming_products, movie_products])
# ```

# %% [markdown]
# ## 4.
# The [Powerlifting Database](https://www.kaggle.com/open-powerlifting/powerlifting-database) dataset on Kaggle includes one CSV table for powerlifting meets and a separate one for powerlifting competitors. Run the cell below to load these datasets into dataframes:

# %%
powerlifting_meets = pd.read_csv("../input/powerlifting-database/meets.csv")
powerlifting_competitors = pd.read_csv("../input/powerlifting-database/openpowerlifting.csv")

# %%
#powerlifting_meets
#powerlifting_meets.set_index('MeetID')

#powerlifting_competitors
powerlifting_competitors.set_index('MeetID')
# Out:
#                           Name Sex   Equipment   ...    TotalKg Place   Wilks
# MeetID                                           ...
# 0             Angie Belk Terry   F       Wraps   ...     138.35     1  155.05
# 0                  Dawn Bogart   F  Single-ply   ...     401.42     1  456.38
# 0                  Dawn Bogart   F  Single-ply   ...     401.42     1  456.38
# 0                  Dawn Bogart   F         Raw   ...      95.25     1  108.29
# 0                 Destiny Dula   F         Raw   ...     122.47     1  130.47
# 0              Courtney Norris   F       Wraps   ...     392.36     1  424.40
# 0                Maureen Clary   F         Raw   ...     383.28     1  391.98
# 0                Maureen Clary   F         Raw   ...     383.28     1  391.98
# 0       Priscilla Sweat Pardue   F       Wraps   ...     283.49     1  294.25
# 0       Priscilla Sweat Pardue   F         Raw   ...     108.86     1  112.99
# 0                 Kayce Hoover   F       Wraps   ...     340.20     1  354.89
# 0                 Cindy Meeker   F       Wraps   ...     292.56     1  287.67
# 0                 Cindy Meeker   F       Wraps   ...     292.56     1  287.67
# 0        Candice Pardue Maness   F       Wraps   ...     283.49     1  280.44
# 0               Danielle Ortiz   F         Raw   ...     247.22     1  247.64
# 0              Jessica Jenkins   F   Multi-ply   ...     601.01     1  547.81
# 0             Jessica Wissmann   F       Wraps   ...     347.00     1  322.30
# 0                    Emma Love   F         Raw   ...     222.25     1  206.43
# 0                 Kelly Benson   F         Raw   ...     299.37     1  260.25
# 0               Cathy Cranford   F         Raw   ...     226.80     1  203.35
# 0            Alexis Eliopoulos   F       Wraps   ...     492.14     1  428.59
# 0                 Shannon Nash   F         Raw   ...     165.56     1  147.95
# 0                 Paula Bowers   F       Wraps   ...     215.46     1  182.50
# 0              Kevin Gingerich   M         Raw   ...     453.59     2  333.01
# 0                   Juan Bollo   M         Raw   ...     478.54     1  356.03
# 0                James McManus   M       Wraps   ...        NaN    DQ     NaN
# 0                James McManus   M         Raw   ...     272.16     1  194.06
# 0              Scott Faircloth   M       Wraps   ...     469.47     1  346.96
# 0                  Justin Monk   M         Raw   ...     485.35     2  332.27
# 0                  Kevin Londe   M         Raw   ...     542.04     1  369.76
# ...                        ...  ..         ...   ...        ...   ...     ...
# 8481                Fred Bland   M   Multi-ply   ...     247.21     1  163.04
# 8481               James Matta   M   Multi-ply   ...     262.50     1  161.10
# 8481               Greg Powell   M   Multi-ply   ...     347.50     1  212.37
# 8481              Tony Carlino   M   Multi-ply   ...     385.00     1  227.06
# 8481           David Kingwater   M   Multi-ply   ...     292.50     2  167.53
# 8481                 Bob Merkh   M   Multi-ply   ...     340.00     1  193.94
# 8481           Dan Steltenkamp   M   Multi-ply   ...        NaN    DQ     NaN
# 8481             Jonathan Byrd   M   Multi-ply   ...        NaN    DQ     NaN
# 8481              Jesse Luczyk   M   Multi-ply   ...        NaN    DQ     NaN
# 8481            Matt Magnivita   M   Multi-ply   ...     330.00     1  179.63
# 8481         Katrina Bielomyza   F   Multi-ply   ...        NaN    DQ     NaN
# 8481          Allison Lockhart   F   Multi-ply   ...     230.00     2  208.37
# 8481              Diane Gmiter   F   Multi-ply   ...     235.00     1  212.77
# 8481             Sheri Whetham   F   Multi-ply   ...     205.00     2  182.90
# 8481              Molly Headly   F   Multi-ply   ...     220.00     1  193.20
# 8481         Jessica Bowersock   F   Multi-ply   ...     205.00     2  166.30
# 8481              Corey Miceli   M   Multi-ply   ...     370.00     1  209.95
# 8481          Samantha Coleman   F   Multi-ply   ...     250.00     1  192.09
# 8481           Bryan Doderdruk   M   Multi-ply   ...     352.50     2  216.85
# 8481           Shawn Schumaker   M   Multi-ply   ...     365.00     1  223.24
# 8481             Adam Colorado   M   Multi-ply   ...     310.00     5  189.60
# 8481              Zane Geeting   M   Multi-ply   ...     325.00     3  198.03
# 8481          Matthew Ladewski   M   Multi-ply   ...     325.00     4  197.82
# 8481         Alastair MacNicol   M   Multi-ply   ...     305.00     2  184.03
# 8481             Brian Yourist   M   Multi-ply   ...     310.00     1  182.69
# 8481           William Barabas   M   Multi-ply   ...     347.50     2  202.60
# 8481              Justin Zottl   M   Multi-ply   ...     322.50     3  185.77
# 8481             Jake Anderson   M   Multi-ply   ...     367.50     1  211.17
# 8481            Jeff Bumanglag   M   Multi-ply   ...     320.00     3  181.85
# 8481             Shane Hammock   M   Multi-ply   ...     362.50     2  205.18
#
# [386414 rows x 16 columns]

# %% [markdown]
# Both tables include references to a `MeetID`, a unique key for each meet (competition) included in the database. Using this, generate a dataset combining the two tables into one.

# %%
powerlifting_combined = powerlifting_meets.set_index('MeetID').join(
                        powerlifting_competitors.set_index('MeetID'))

q4.check()
powerlifting_combined.BestDeadliftKg.mean()
# Out:
# Correct
# 195.04063341796547

# %%
#q4.hint()
q4.solution()
# Out:
# Solution:
# ```python
# powerlifting_combined = powerlifting_meets.set_index("MeetID").join(powerlifting_competitors.set_index("MeetID"))
# ```

# %% [markdown]
# # Congratulations
#
# You've finished the Pandas micro-course.  Many data scientist feel efficiency with Pandas is the most useful and practical skill they have, because it allows you to progress quickly in any project you have.
#
# The skills you've built will pay off well if you keep using them.

# %% [markdown]
# ---
# **[Pandas Micro-Course Home Page](https://www.kaggle.com/learn/pandas)**
